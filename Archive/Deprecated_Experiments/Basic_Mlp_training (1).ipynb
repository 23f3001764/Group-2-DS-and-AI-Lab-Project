# %% [markdown]
# ## GPU Check + Setup

# %%
import torch
print(f"CUDA available : {torch.cuda.is_available()}")
print(f"GPU            : {torch.cuda.get_device_name(0) if torch.cuda.is_available() else '❌ No GPU — go to Runtime > Change runtime type > T4'}")

from google.colab import drive
drive.mount('/content/drive')
# !pip install -q ultralytics scikit-learn
# Out:
# CUDA available : True
# GPU            : Tesla T4
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Download Custom Dataset

# %%
import gdown, os, zipfile

os.makedirs("/content/custom_dataset", exist_ok=True)

# ── DOWNLOAD ZIP ──────────────────────────────────────────────
print("⏳ Downloading custom dataset zip...")
gdown.download(
    "https://drive.google.com/uc?id=1Vyi1GgABlR6V_QvNkNuovnlLnWZID8hA",
    "/content/custom_dataset.zip",
    quiet=False
)

size = os.path.getsize("/content/custom_dataset.zip")
print(f"✅ Downloaded: {size/1e6:.1f} MB")

# ── UNZIP ─────────────────────────────────────────────────────
print("⏳ Extracting...")
with zipfile.ZipFile("/content/custom_dataset.zip", 'r') as z:
    z.extractall("/content/custom_dataset")
print("✅ Extracted!")

# ── SHOW FULL STRUCTURE ───────────────────────────────────────
print("\n📁 Contents:")
for root, dirs, files in os.walk("/content/custom_dataset"):
    level = root.replace("/content/custom_dataset", "").count(os.sep)
    indent = "  " * level
    print(f"{indent}📁 {os.path.basename(root)}/")
    sub = "  " * (level + 1)
    imgs = [f for f in files if f.lower().endswith(('.jpg','.jpeg','.png'))]
    csvs = [f for f in files if f.endswith('.csv')]
    if imgs:
        print(f"{sub}🖼️  {len(imgs)} images")
        for f in imgs[:3]:
            print(f"{sub}   {f}")
        if len(imgs) > 3:
            print(f"{sub}   ... ({len(imgs)-3} more)")
    for c in csvs:
        print(f"{sub}📄 {c}")

# ── VERIFY ────────────────────────────────────────────────────
all_imgs = []
for root, dirs, files in os.walk("/content/custom_dataset"):
    all_imgs += [os.path.join(root,f) for f in files
                 if f.lower().endswith(('.jpg','.jpeg','.png'))]
all_csvs = []
for root, dirs, files in os.walk("/content/custom_dataset"):
    all_csvs += [os.path.join(root,f) for f in files if f.endswith('.csv')]

print(f"\n✅ Total images : {len(all_imgs)}")
print(f"✅ CSV files    : {all_csvs}")
# Out:
# ⏳ Downloading custom dataset zip...
# Downloading...
# From (original): https://drive.google.com/uc?id=1Vyi1GgABlR6V_QvNkNuovnlLnWZID8hA
# From (redirected): https://drive.google.com/uc?id=1Vyi1GgABlR6V_QvNkNuovnlLnWZID8hA&confirm=t&uuid=eecdda73-2437-4438-8a39-bbddf69da1e5
# To: /content/custom_dataset.zip
# 100%|██████████| 61.3M/61.3M [00:01<00:00, 50.8MB/s]
# ✅ Downloaded: 61.3 MB
# ⏳ Extracting...
# ✅ Extracted!
#
# 📁 Contents:
# 📁 custom_dataset/
#   📁 New folder/
#     🖼️  76 images
#        Koozh.jpeg
#        Greenchutney_250.jpg
#        Bhindimasala_200.jpg
#        ... (73 more)
#     📄 Label.csv
#
# ✅ Total images : 76
# ✅ CSV files    : ['/content/custom_dataset/New folder/Label.csv']

# %% [markdown]
# ## Load & Clean CSV

# %%
import pandas as pd
import numpy as np
import os, glob

df = pd.read_csv("/content/custom_dataset/New folder/Label.csv")
df.columns = df.columns.str.strip().str.lower().str.replace('﻿','')
df = df.rename(columns={"image_name":"image_name", "weight":"weight", "class":"food_class"})
df['image_name'] = df['image_name'].astype(str).str.strip()
df['food_class'] = df['food_class'].astype(str).str.strip()

print(f"✅ CSV loaded: {len(df)} rows")

# ── FIND ALL IMAGES ───────────────────────────────────────────
image_dir  = "/content/custom_dataset"
all_images = glob.glob(f"{image_dir}/**/*", recursive=True)
all_images = [f for f in all_images if f.lower().endswith(('.jpg','.jpeg','.png'))]

print(f"\n📁 All images found ({len(all_images)}):")
for p in sorted(all_images):
    print(f"  {os.path.basename(p)}")

# ── BUILD LOOKUP WITH MULTIPLE KEYS ──────────────────────────
img_lookup = {}
for path in all_images:
    basename = os.path.basename(path)
    stem     = os.path.splitext(basename)[0]

    # Store multiple versions of the name as keys
    keys = [
        stem,                                    # original
        stem.lower(),                            # lowercase
        stem.lower().replace(' ', '_'),          # spaces → underscores
        stem.lower().replace('_', ' '),          # underscores → spaces
        stem.lower().replace(' ', ''),           # no spaces
        stem.lower().replace('_', ''),           # no underscores
    ]
    for key in keys:
        if key not in img_lookup:
            img_lookup[key] = path

def find_image(name):
    stem = os.path.splitext(str(name).strip())[0]

    # Try all key variants
    variants = [
        stem,
        stem.lower(),
        stem.lower().replace(' ', '_'),
        stem.lower().replace('_', ' '),
        stem.lower().replace(' ', ''),
        stem.lower().replace('_', ''),
    ]
    for v in variants:
        if v in img_lookup:
            return img_lookup[v]

    # Last resort: partial match
    stem_clean = stem.lower().replace(' ', '').replace('_', '')
    for key, path in img_lookup.items():
        key_clean = key.lower().replace(' ', '').replace('_', '')
        if stem_clean == key_clean:
            return path

    return None

df['image_path'] = df['image_name'].apply(find_image)

matched   = df['image_path'].notna().sum()
unmatched = df['image_path'].isna().sum()
print(f"\n✅ Matched  : {matched} rows")
print(f"⚠️  Unmatched: {unmatched} rows")

if unmatched > 0:
    print("\nStill unmatched — these files may be missing from the folder:")
    for name in df[df['image_path'].isna()]['image_name'].tolist():
        print(f"  CSV name: '{name}'")

df = df.dropna(subset=['image_path']).reset_index(drop=True)
print(f"\n✅ Final dataset: {len(df)} rows, {df['image_path'].nunique()} unique images")
# Out:
# ✅ CSV loaded: 88 rows
#
# 📁 All images found (76):
#   AlooMasala.jpeg
#   Appam_100.jpg
#   Beetroot poriyal.jpg
#   Beetrootporiyal_180.jpg
#   Bhatura_100.jpg
#   Bhindi Masala.jpg
#   Bhindimasala_200.jpg
#   Boiledegg_100.jpg
#   Carrotporiyal_180.jpg
#   Chai_150.jpg
#   Chicken biryani.jpeg
#   Chicken65_420.jpg
#   Chole_350.jpg
#   Dal_350.jpg
#   Dumaloo_350.jpeg
#   Fishcurry_380.jpg
#   Ghevar_450.jpg
#   Greenchutney_250.jpg
#   IMG_20200414_181451.jpg
#   IMG_20200504_185825.jpg
#   IMG_20200507_175052.jpg
#   IMG_20200512_171423.jpg
#   IMG_20200601_151529.jpg
#   IMG_20200616_221408.jpg
#   IMG_20200722_174130.jpg
#   IMG_20200726_084542.jpg
#   IMG_20200816_085331.jpg
#   IMG_20210116_145321.jpg
#   IMG_20210808_203051.jpg
#   Jalebi_200.jpg
#   Kali.jpg
#   Kebab_250.jpg
#   Koozh.jpeg
#   Kulfi_160.jpg
#   Lassi_280.jpg
#   Mushroom biryani.jpeg
#   Mutton Biryani.jpeg
#   MuttonCurry.jpeg
#   Nandu masala.jpeg
#   Paneer biryani.jpeg
#   Panner masala.jpeg
#   PrawnThokku.jpg
#   Rajma-curry.jpg
#   Samosa_100.jpg
#   Veg Biryani.jpeg
#   Vegbiryani_350.jpeg
#   aloo_gobi.jpg
#   biryani_1.jpeg
#   coconut_chutney_1.jpeg
#   dosa_1.jpeg
#   gulab_jamun.jpg
#   idli.jpeg
#   idli_1.jpeg
#   kaara_chutney_1.jpeg
#   kheer_1.jpeg
#   lassi.jpg
#   lemon rice.jpeg
#   navrattan_korma.jpg
#   onion_pakoda_1.jpeg
#   onion_pakoda_2.jpeg
#   paal_kozhukattai_1.jpeg
#   palak_paneer.jpg
#   paruppu_vadai_1.jpeg
#   pidi_kozhkatai_1.jpeg
#   pidi_kozhkatai_2.jpeg
#   poha.jpg
#   prawn_thokku.jpg
#   pudina chutney.jpg
#   ras_malai.jpg
#   rasmalai.jpg
#   sambhar_1.jpeg
#   sambhar_rice_1.jpeg
#   shahi paneer.jpg
#   vadai_1.jpeg
#   ven_pongal_1.jpeg
#   white_rice_1.jpeg
#
# ✅ Matched  : 87 rows
# ⚠️  Unmatched: 1 rows
#
# Still unmatched — these files may be missing from the folder:
#   CSV name: 'uzuntha vadai_1'
#
# ✅ Final dataset: 87 rows, 74 unique images

# %% [markdown]
# ## Train/Test Split (by unique image)

# %%
from sklearn.model_selection import train_test_split

# Split by unique image (so same image doesn't appear in both sets)
unique_images = df['image_path'].unique()
train_imgs, test_imgs = train_test_split(unique_images, test_size=0.2, random_state=42)

df_train = df[df['image_path'].isin(train_imgs)].reset_index(drop=True)
df_test  = df[df['image_path'].isin(test_imgs)].reset_index(drop=True)

print(f"✅ Train: {len(df_train)} rows | {len(train_imgs)} unique images")
print(f"✅ Test : {len(df_test)}  rows | {len(test_imgs)}  unique images")
print(f"\nTrain classes: {df_train['food_class'].nunique()} unique")
print(f"Test  classes: {df_test['food_class'].nunique()}  unique")
# Out:
# ✅ Train: 70 rows | 59 unique images
# ✅ Test : 17  rows | 15  unique images
#
# Train classes: 51 unique
# Test  classes: 14  unique

# %%
from ultralytics import YOLO

# ── DOWNLOAD DEMO MODEL FROM PUBLIC DRIVE ────────────────────
import gdown, os

os.makedirs("/content/models", exist_ok=True)

gdown.download_folder(
    url="https://drive.google.com/drive/folders/1bK3Ia12fVSq4G8yITiwxDZRhuRFmhqhm",
    output="/content/models",
    quiet=False,
    use_cookies=False
)

# Auto-find demo model (v3)
import glob
pt_files  = glob.glob("/content/models/**/*.pt", recursive=True)
demo_path = next((f for f in pt_files if 'v3' in f or 'demo' in f), pt_files[0] if pt_files else None)

print(f"📌 Demo model: {demo_path}")
yolo_model = YOLO(demo_path)
print("✅ YOLO demo model loaded!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Retrieving folder contents
# Retrieving folder 1ljrrE7auR20p-tBtvhe6dCrqhNW3PhGV nutrivision_v1
# Retrieving folder 1JiPw158v3ySH715xRH8t1M8A84Hm3gJD weights
# Processing file 1ptxYRb3OGiCcD7k5uiaOXEReyKpYOHGA best.pt
# Processing file 1ueRoOvzAJuSWuGVonzpBT-9RET5YCMd2 last.pt
# Processing file 1p5gHVDo8WRNA5wawA4dn0_Pw9f3hQevg args.yaml
# Processing file 1NaoJKHWCH-YUOT2gE5Cly05NilV1BYTK labels.jpg
# Processing file 1dN0NcChqUjqFVcvjO9BzxWoprO6EbCcf results.csv
# Processing file 1r_taZ0fkLxReKOyAmufnCiLpy_QmdzzS train_batch0.jpg
# Processing file 1sqqoeqryJCI_H2mWheWRvKMSPDgTVUbU train_batch1.jpg
# Processing file 18SXgkOt9syyZr6RgxeRODryyKdZOLL2o train_batch2.jpg
# Retrieving folder 199010GA3xdpn5DwPrTnAQ1fXhEdFH2D4 nutrivision_v2_fast
# Retrieving folder 1vAj6AgwttkzFnpp-I5Cc-Z5GomHA0FGn weights
# Processing file 1U1Zmy7dj5xdEBg9oRO1-cyQllyPI6w7- args.yaml
# Processing file 1FaTm1fFvdyGpgyEjTbmlnLC8VKrDHm8u labels.jpg
# Processing file 1NRkUtnCAE82ymSs2mYpYPwdSUvSuo-5L train_batch0.jpg
# Processing file 1P0F5tL89Y0CSq2wMp_2cCJcDTK75PUFj train_batch1.jpg
# Processing file 1fThCj5eKobEhkN-LDVHBxursuO2uMohB train_batch2.jpg
# Retrieving folder 1NhOA_tWMqrmwbdJ0jMSBlfrohGjCc2zP nutrivision_v3_demo
# Retrieving folder 1w1hOp2H9b3DziAno1jSbkAp9iLvpJ5Bv weights
# Processing file 1NpHnY9sFhmwuBXI2mvOsuxsy8D34Avrc best.pt
# Processing file 1PdPpayg4CBS5lzUlHzu95LZ3tWqWL13O last.pt
# Processing file 1uXgyDno70wCKm-35n2kBKWW_KVi9nBBy args.yaml
# Processing file 1-iq9agsdJvKr9kRPVJk8ZeGpwZ3qLnAW BoxF1_curve.png
# Processing file 1QxsuhAOPCkAZwtHjMv5GvCONJ6mtxj8D BoxP_curve.png
# Processing file 1Y05wKSrgwyemcX_1lhLiocktoV88GZb6 BoxPR_curve.png
# Processing file 1EZz_vRC-S6QO8fC2AooYlxJODPWeC_zi BoxR_curve.png
# Processing file 1jnPQOQKR6YTchLMz09BhCMAF01PT3aZP confusion_matrix_normalized.png
# Processing file 1sATWzYO62UusuNMv56YT5WvYsTLJ4eDM confusion_matrix.png
# Processing file 10-S7Ky0SU3eofxFruABuJOuad-mGPGJr labels.jpg
# Processing file 16fZtFkhDYsbjMaEkjwcJBzqhFdGUfJ5m results.csv
# Processing file 110X5q_WNrRVysuPyxUb_Yggr0jFXNLOW results.png
# Processing file 1UcVR8FhL_JeIfzADoFlEn0brOkALbeDq train_batch0.jpg
# Processing file 17s4ASPhVY2cEE21-XbhVYVRhdItlX16f train_batch1.jpg
# Processing file 1rJQChHMjL2j01w-ZyzXEOFaGPDNExcrZ train_batch2.jpg
# Processing file 1Khe4hAMdc3xpH6-_WQx1QEQfCyA3ST1M train_batch10330.jpg
# Processing file 1TgWhZIu3Z651DJlZKnvN5WfoqNzUMqbU train_batch10331.jpg
# Processing file 1ZyWnxsEO_zQwTklRFGu_d703MPL2wwgB train_batch10332.jpg
# Processing file 1HA6DpfKz8fhIFYNTOJl24EXFsd8OO4dH val_batch0_labels.jpg
# Processing file 1rMOmOqWCg3TX58Bf8OWKuHM9dODBv93A val_batch0_pred.jpg
# Processing file 1kfIZ2bdezPEoVcK--M2LrD-Jf_8b_kCP val_batch1_labels.jpg
# Processing file 14_JKscdQp5M8NQ_2ruVrfcGXJ5ehj5G1 val_batch1_pred.jpg
# Processing file 109vunHN-JuYFdAr222WWCqR7P5u7oq3f val_batch2_labels.jpg
# Processing file 1LlGvwJJIMNA4F7PlFZxGh2IuL2523mce val_batch2_pred.jpg
# Processing file 1fh9WfY7nv0GUkhMQPuGknPUWCVE8qEIt per_class_results_v1.csv
# Processing file 1Jj3OYdl4vSKZEx6Y1fgFKpdHI5v4BcVu per_class_results_v3.csv
# Processing file 1gNeuSf9kW296BU8TxHeuoPiGbW3R3U0A test_detections_v1.png
# Processing file 1Vf9fH25qxA_w8K-cqO8Vt-wTw-DypzS5 test_detections_v3_demo.png
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=1ptxYRb3OGiCcD7k5uiaOXEReyKpYOHGA
# From (redirected): https://drive.google.com/uc?id=1ptxYRb3OGiCcD7k5uiaOXEReyKpYOHGA&confirm=t&uuid=99abecef-5c0d-4111-9bfe-2b7ef29442d1
# To: /content/models/nutrivision_v1/weights/best.pt
# 100%|██████████| 55.8M/55.8M [00:00<00:00, 57.9MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1ueRoOvzAJuSWuGVonzpBT-9RET5YCMd2
# From (redirected): https://drive.google.com/uc?id=1ueRoOvzAJuSWuGVonzpBT-9RET5YCMd2&confirm=t&uuid=5a27d867-fc51-4f19-89eb-ae842258a10d
# To: /content/models/nutrivision_v1/weights/last.pt
# 100%|██████████| 55.8M/55.8M [00:00<00:00, 57.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1p5gHVDo8WRNA5wawA4dn0_Pw9f3hQevg
# To: /content/models/nutrivision_v1/args.yaml
# 100%|██████████| 1.68k/1.68k [00:00<00:00, 7.40MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1NaoJKHWCH-YUOT2gE5Cly05NilV1BYTK
# To: /content/models/nutrivision_v1/labels.jpg
# 100%|██████████| 183k/183k [00:00<00:00, 3.62MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1dN0NcChqUjqFVcvjO9BzxWoprO6EbCcf
# To: /content/models/nutrivision_v1/results.csv
# 100%|██████████| 1.03k/1.03k [00:00<00:00, 4.99MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1r_taZ0fkLxReKOyAmufnCiLpy_QmdzzS
# To: /content/models/nutrivision_v1/train_batch0.jpg
# 100%|██████████| 823k/823k [00:00<00:00, 9.38MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1sqqoeqryJCI_H2mWheWRvKMSPDgTVUbU
# To: /content/models/nutrivision_v1/train_batch1.jpg
# 100%|██████████| 665k/665k [00:00<00:00, 6.84MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=18SXgkOt9syyZr6RgxeRODryyKdZOLL2o
# To: /content/models/nutrivision_v1/train_batch2.jpg
# 100%|██████████| 671k/671k [00:00<00:00, 8.38MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1U1Zmy7dj5xdEBg9oRO1-cyQllyPI6w7-
# To: /content/models/nutrivision_v2_fast/args.yaml
# 100%|██████████| 1.74k/1.74k [00:00<00:00, 7.98MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1FaTm1fFvdyGpgyEjTbmlnLC8VKrDHm8u
# To: /content/models/nutrivision_v2_fast/labels.jpg
# 100%|██████████| 183k/183k [00:00<00:00, 3.07MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1NRkUtnCAE82ymSs2mYpYPwdSUvSuo-5L
# To: /content/models/nutrivision_v2_fast/train_batch0.jpg
# 100%|██████████| 743k/743k [00:00<00:00, 7.25MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1P0F5tL89Y0CSq2wMp_2cCJcDTK75PUFj
# To: /content/models/nutrivision_v2_fast/train_batch1.jpg
# 100%|██████████| 672k/672k [00:00<00:00, 8.13MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1fThCj5eKobEhkN-LDVHBxursuO2uMohB
# To: /content/models/nutrivision_v2_fast/train_batch2.jpg
# 100%|██████████| 681k/681k [00:00<00:00, 8.40MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1NpHnY9sFhmwuBXI2mvOsuxsy8D34Avrc
# To: /content/models/nutrivision_v3_demo/weights/best.pt
# 100%|██████████| 18.7M/18.7M [00:00<00:00, 58.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1PdPpayg4CBS5lzUlHzu95LZ3tWqWL13O
# To: /content/models/nutrivision_v3_demo/weights/last.pt
# 100%|██████████| 18.7M/18.7M [00:00<00:00, 74.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1uXgyDno70wCKm-35n2kBKWW_KVi9nBBy
# To: /content/models/nutrivision_v3_demo/args.yaml
# 100%|██████████| 1.74k/1.74k [00:00<00:00, 2.10MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-iq9agsdJvKr9kRPVJk8ZeGpwZ3qLnAW
# To: /content/models/nutrivision_v3_demo/BoxF1_curve.png
# 100%|██████████| 1.26M/1.26M [00:00<00:00, 10.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1QxsuhAOPCkAZwtHjMv5GvCONJ6mtxj8D
# To: /content/models/nutrivision_v3_demo/BoxP_curve.png
# 100%|██████████| 1.14M/1.14M [00:00<00:00, 7.84MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Y05wKSrgwyemcX_1lhLiocktoV88GZb6
# To: /content/models/nutrivision_v3_demo/BoxPR_curve.png
# 100%|██████████| 444k/444k [00:00<00:00, 5.39MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1EZz_vRC-S6QO8fC2AooYlxJODPWeC_zi
# To: /content/models/nutrivision_v3_demo/BoxR_curve.png
# 100%|██████████| 958k/958k [00:00<00:00, 7.30MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1jnPQOQKR6YTchLMz09BhCMAF01PT3aZP
# To: /content/models/nutrivision_v3_demo/confusion_matrix_normalized.png
# 100%|██████████| 449k/449k [00:00<00:00, 4.67MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1sATWzYO62UusuNMv56YT5WvYsTLJ4eDM
# To: /content/models/nutrivision_v3_demo/confusion_matrix.png
# 100%|██████████| 450k/450k [00:00<00:00, 1.62MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=10-S7Ky0SU3eofxFruABuJOuad-mGPGJr
# To: /content/models/nutrivision_v3_demo/labels.jpg
# 100%|██████████| 183k/183k [00:00<00:00, 4.27MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=16fZtFkhDYsbjMaEkjwcJBzqhFdGUfJ5m
# To: /content/models/nutrivision_v3_demo/results.csv
# 100%|██████████| 1.95k/1.95k [00:00<00:00, 8.53MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=110X5q_WNrRVysuPyxUb_Yggr0jFXNLOW
# To: /content/models/nutrivision_v3_demo/results.png
# 100%|██████████| 288k/288k [00:00<00:00, 3.72MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1UcVR8FhL_JeIfzADoFlEn0brOkALbeDq
# To: /content/models/nutrivision_v3_demo/train_batch0.jpg
# 100%|██████████| 482k/482k [00:00<00:00, 6.60MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=17s4ASPhVY2cEE21-XbhVYVRhdItlX16f
# To: /content/models/nutrivision_v3_demo/train_batch1.jpg
# 100%|██████████| 459k/459k [00:00<00:00, 6.43MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1rJQChHMjL2j01w-ZyzXEOFaGPDNExcrZ
# To: /content/models/nutrivision_v3_demo/train_batch2.jpg
# 100%|██████████| 443k/443k [00:00<00:00, 6.35MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Khe4hAMdc3xpH6-_WQx1QEQfCyA3ST1M
# To: /content/models/nutrivision_v3_demo/train_batch10330.jpg
# 100%|██████████| 433k/433k [00:00<00:00, 5.10MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1TgWhZIu3Z651DJlZKnvN5WfoqNzUMqbU
# To: /content/models/nutrivision_v3_demo/train_batch10331.jpg
# 100%|██████████| 464k/464k [00:00<00:00, 6.55MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ZyWnxsEO_zQwTklRFGu_d703MPL2wwgB
# To: /content/models/nutrivision_v3_demo/train_batch10332.jpg
# 100%|██████████| 462k/462k [00:00<00:00, 5.53MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1HA6DpfKz8fhIFYNTOJl24EXFsd8OO4dH
# To: /content/models/nutrivision_v3_demo/val_batch0_labels.jpg
# 100%|██████████| 568k/568k [00:00<00:00, 5.32MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1rMOmOqWCg3TX58Bf8OWKuHM9dODBv93A
# To: /content/models/nutrivision_v3_demo/val_batch0_pred.jpg
# 100%|██████████| 575k/575k [00:00<00:00, 5.40MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1kfIZ2bdezPEoVcK--M2LrD-Jf_8b_kCP
# To: /content/models/nutrivision_v3_demo/val_batch1_labels.jpg
# 100%|██████████| 620k/620k [00:00<00:00, 7.98MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=14_JKscdQp5M8NQ_2ruVrfcGXJ5ehj5G1
# To: /content/models/nutrivision_v3_demo/val_batch1_pred.jpg
# 100%|██████████| 617k/617k [00:00<00:00, 6.57MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=109vunHN-JuYFdAr222WWCqR7P5u7oq3f
# To: /content/models/nutrivision_v3_demo/val_batch2_labels.jpg
# 100%|██████████| 679k/679k [00:00<00:00, 5.97MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1LlGvwJJIMNA4F7PlFZxGh2IuL2523mce
# To: /content/models/nutrivision_v3_demo/val_batch2_pred.jpg
# 100%|██████████| 691k/691k [00:00<00:00, 8.36MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1fh9WfY7nv0GUkhMQPuGknPUWCVE8qEIt
# To: /content/models/per_class_results_v1.csv
# 100%|██████████| 2.60k/2.60k [00:00<00:00, 3.15MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Jj3OYdl4vSKZEx6Y1fgFKpdHI5v4BcVu
# To: /content/models/per_class_results_v3.csv
# 100%|██████████| 2.66k/2.66k [00:00<00:00, 10.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1gNeuSf9kW296BU8TxHeuoPiGbW3R3U0A
# To: /content/models/test_detections_v1.png
# 100%|██████████| 7.59M/7.59M [00:00<00:00, 37.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Vf9fH25qxA_w8K-cqO8Vt-wTw-DypzS5
# To: /content/models/test_detections_v3_demo.png
# 100%|██████████| 7.19M/7.19M [00:00<00:00, 30.3MB/s]
# Download completed
# 📌 Demo model: /content/models/nutrivision_v3_demo/weights/last.pt
# ✅ YOLO demo model loaded!

# %% [markdown]
# ## Run YOLO on All Custom Images → Extract Pixel Features
# YOLO + SAM-2 Segmentation

# %%
# ── INSTALL SAM-2 ─────────────────────────────────────────────
# !pip install -q sam2

import torch
import numpy as np
import cv2
import pandas as pd
from tqdm import tqdm
from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor

# ── LOAD SAM-2 MODEL (auto downloads ~180MB) ──────────────────
print("⏳ Loading SAM-2...")
predictor = SAM2ImagePredictor.from_pretrained("facebook/sam2-hiera-small")
print("✅ SAM-2 loaded!")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 kB 6.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 16.2 MB/s eta 0:00:00
#   Building wheel for sam2 (pyproject.toml) ... done
#   Building wheel for iopath (setup.py) ... done
# ⏳ Loading SAM-2...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# sam2_hiera_small.pt:   0%|          | 0.00/184M [00:00<?, ?B/s]
# ✅ SAM-2 loaded!

# %%
def extract_features_with_sam2(image_path, yolo_model, sam_predictor, target_class):
    """
    YOLO → BBox → SAM2 → Pixel mask → real food pixel area
    """
    img_bgr = cv2.imread(image_path)
    if img_bgr is None:
        return None

    img_rgb  = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    h, w     = img_rgb.shape[:2]
    img_area = h * w

    # ── STEP 1: YOLO DETECTION ────────────────────────────────
    results = yolo_model.predict(
        source=image_path, conf=0.15, verbose=False
    )[0]

    if results.boxes is None or len(results.boxes) == 0:
        return None

    # Find best matching box for target class
    target_clean = target_class.strip().lower().replace(' ', '_')
    best_box     = None
    best_conf    = 0.0

    for box in results.boxes:
        cls_name = yolo_model.names[int(box.cls)].strip().lower()
        conf     = float(box.conf)
        if cls_name == target_clean and conf > best_conf:
            best_conf = conf
            best_box  = box

    # Fallback to highest confidence if class not found
    if best_box is None:
        best_box = max(results.boxes, key=lambda b: float(b.conf))

    # Get bbox coordinates
    x1, y1, x2, y2 = [int(v) for v in best_box.xyxy[0].tolist()]
    bbox_xyxy       = np.array([x1, y1, x2, y2])

    # ── STEP 2: SAM-2 SEGMENTATION ────────────────────────────
    with torch.inference_mode():
        sam_predictor.set_image(img_rgb)
        masks, scores, _ = sam_predictor.predict(
            box=bbox_xyxy[None, :],   # SAM expects [1, 4]
            multimask_output=False,
        )

    # masks shape: (1, H, W) — take first mask
    mask       = masks[0].astype(np.uint8)  # binary: 0 or 1
    pixel_food = int(mask.sum())             # count of food pixels

    # ── STEP 3: PLATE AREA ────────────────────────────────────
    # Use full image area as plate proxy
    # (can be improved later with plate detection)
    pixel_plate = img_area
    pixel_ratio = pixel_food / pixel_plate if pixel_plate > 0 else 0

    return {
        'pixel_food'  : pixel_food,
        'pixel_plate' : pixel_plate,
        'pixel_ratio' : pixel_ratio,
        'conf'        : float(best_box.conf),
        'detected_cls': yolo_model.names[int(best_box.cls)],
        'mask'        : mask,   # keep for visualization
    }

# ── PROCESS ALL ROWS ──────────────────────────────────────────
print("⏳ Running YOLO + SAM-2 on all custom images...")
features_list = []

for _, row in tqdm(df.iterrows(), total=len(df)):
    feat = extract_features_with_sam2(
        row['image_path'], yolo_model, predictor, row['food_class']
    )
    if feat:
        feat.pop('mask')           # remove mask array from dataframe
        feat['image_path'] = row['image_path']
        feat['food_class'] = row['food_class']
        feat['weight']     = row['weight']
        features_list.append(feat)
    else:
        print(f"  ⚠️  No detection: {row['image_name']} ({row['food_class']})")

df_features = pd.DataFrame(features_list)
print(f"\n✅ Features extracted: {len(df_features)}/{len(df)} rows")
print(df_features.head())
# Out:
# ⏳ Running YOLO + SAM-2 on all custom images...
#   6%|▌         | 5/87 [00:03<00:37,  2.17it/s]
#   ⚠️  No detection: pidi_kozhkatai_1 (pidi_kolukattai)
#   8%|▊         | 7/87 [00:03<00:23,  3.44it/s]
#   ⚠️  No detection: onion pakoda_1 (onion_pakoda)
#   ⚠️  No detection: onion pakoda_1 (onion_pakoda)
#  11%|█▏        | 10/87 [00:04<00:14,  5.18it/s]
#   ⚠️  No detection: sambhar_1 (sambar)
#  31%|███       | 27/87 [00:10<00:22,  2.63it/s]
#   ⚠️  No detection: IMG_20200722_174130 (onion_pakoda)
#   ⚠️  No detection: IMG_20200722_174130 (kaara_chutney)
#  46%|████▌     | 40/87 [00:19<00:28,  1.65it/s]
#   ⚠️  No detection: Beetrootporiyal_180 (beetroot_poriyal)
#  51%|█████     | 44/87 [00:20<00:14,  2.90it/s]
#   ⚠️  No detection: Bhindimasala_200 (bhindi_masala)
#   ⚠️  No detection: Boiledegg_100 (boiled_egg)
#  64%|██████▍   | 56/87 [00:23<00:08,  3.65it/s]
#   ⚠️  No detection: Kulfi_160 (kulfi)
#  66%|██████▌   | 57/87 [00:24<00:08,  3.37it/s]
#   ⚠️  No detection: Lassi_280 (lassi)
#  69%|██████▉   | 60/87 [00:25<00:09,  2.99it/s]
#   ⚠️  No detection: Vegbiryani_350 (veg_biryani)
#  76%|███████▌  | 66/87 [00:27<00:05,  3.54it/s]
#   ⚠️  No detection: Kali.jpg (kali)
# 100%|██████████| 87/87 [00:32<00:00,  2.67it/s]
# ✅ Features extracted: 74/87 rows
#    pixel_food  pixel_plate  pixel_ratio      conf     detected_cls  \
# 0      657212      1513840     0.434136  0.481079  pidi_kolukattai
# 1     5561439      7556472     0.735984  0.282572  chicken_biryani
# 2      210878       921600     0.228817  0.192693           ghevar
# 3      258025       921600     0.279975  0.341377            lassi
# 4      190732       921600     0.206957  0.182858            koozh
#
#                                           image_path       food_class  weight
# 0  /content/custom_dataset/New folder/IMG_2020041...           jalebi     115
# 1  /content/custom_dataset/New folder/IMG_2020050...      veg_biryani     340
# 2  /content/custom_dataset/New folder/biryani_1.jpeg   mutton_biryani     130
# 3  /content/custom_dataset/New folder/coconut_chu...  coconut_chutney      60
# 4     /content/custom_dataset/New folder/idli_1.jpeg             idli      36

# %% [markdown]
# Clean Features (remove wrong detections)

# %%
print(f"Before cleaning: {len(df_features)} rows")

df_features['class_match'] = (
    df_features['food_class'].str.strip().str.lower().str.replace(' ','_') ==
    df_features['detected_cls'].str.strip().str.lower().str.replace(' ','_')
)

matched    = df_features['class_match'].sum()
mismatched = (~df_features['class_match']).sum()

print(f"  ✅ Matched    : {matched}")
print(f"  ⚠️  Mismatched : {mismatched}")
print("\nMismatched rows:")
print(df_features[~df_features['class_match']][
    ['food_class','detected_cls','weight','conf']
].to_string())

# Keep only correct detections + conf >= 0.20
df_features = df_features[
    df_features['class_match'] & (df_features['conf'] >= 0.20)
].reset_index(drop=True)

print(f"\n✅ Clean dataset: {len(df_features)} rows")
print(f"   Weight range : {df_features['weight'].min()}g — {df_features['weight'].max()}g")
print(f"   Unique classes: {df_features['food_class'].nunique()}")
# Out:
# Before cleaning: 74 rows
#   ✅ Matched    : 39
#   ⚠️  Mismatched : 35
#
# Mismatched rows:
#          food_class     detected_cls  weight      conf
# 0            jalebi  pidi_kolukattai     115  0.481079
# 1       veg_biryani  chicken_biryani     340  0.282572
# 2    mutton_biryani           ghevar     130  0.192693
# 3   coconut_chutney            lassi      60  0.341377
# 4              idli            koozh      36  0.182858
# 8   coconut_chutney            lassi      60  0.341377
# 11      parupu_vada  pidi_kolukattai      55  0.487979
# 12       ven_pongal         kalakand     187  0.448586
# 13    kaara_chutney      rajma_curry     103  0.340015
# 15           samosa  pidi_kolukattai     595  0.201132
# 16           sambar  pidi_kolukattai     180  0.663253
# 17             idli  pidi_kolukattai     540  0.663253
# 18             dosa  pidi_kolukattai      75  0.663253
# 20         rasgulla  pidi_kolukattai     295  0.573367
# 22          bhatura            chole     120  0.614388
# 23       white_rice             idli     180  0.388661
# 24              dal             idli     155  0.388661
# 25    paneer_masala             idli     140  0.388661
# 26        aloo_gobi    sambar_satham     230  0.254281
# 27       aloo_matar    sambar_satham     245  0.254281
# 28              dal  coconut_chutney     160  0.604206
# 29          kachori  coconut_chutney     240  0.604206
# 30           jalebi  coconut_chutney     165  0.604206
# 31            rabri  coconut_chutney     125  0.604206
# 32            kheer  coconut_chutney     180  0.604206
# 40         dum_aloo     kadai_paneer     350  0.288709
# 46           samosa    sambar_satham     100  0.311503
# 49  navrattan_korma     prawn_thokku     245  0.333339
# 50      aloo_masala     prawn_thokku     220  0.926800
# 57     mutton_curry     prawn_thokku     260  0.557286
# 60    paneer_masala     prawn_thokku     240  0.643697
# 62      rajma_curry     prawn_thokku     250  0.347559
# 63      veg_biryani   paneer_biryani     340  0.828144
# 64        aloo_gobi   carrot_poriyal     230  0.743253
# 73     shahi_paneer       white_rice     260  0.421687
#
# ✅ Clean dataset: 38 rows
#    Weight range : 82g — 450g
#    Unique classes: 33

# %% [markdown]
# ##  Prepare MLP Features

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
import joblib, os

le = LabelEncoder()
df_features['class_encoded'] = le.fit_transform(df_features['food_class'])

feature_cols = ['pixel_ratio', 'pixel_food', 'pixel_plate', 'class_encoded']
X = df_features[feature_cols].values
y = df_features['weight'].values

print(f"✅ Feature matrix : {X.shape}")
print(f"✅ Weight range   : {y.min():.0f}g — {y.max():.0f}g  |  Mean: {y.mean():.1f}g")

# Split by unique image
unique_images          = df_features['image_path'].unique()
train_imgs, test_imgs  = train_test_split(unique_images, test_size=0.2, random_state=42)

train_mask = df_features['image_path'].isin(train_imgs)
test_mask  = df_features['image_path'].isin(test_imgs)

X_train, y_train = X[train_mask], y[train_mask]
X_test,  y_test  = X[test_mask],  y[test_mask]

scaler  = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

print(f"\n✅ Train: {X_train.shape[0]} samples")
print(f"✅ Test : {X_test.shape[0]}  samples")

os.makedirs("/content/mlp_artifacts", exist_ok=True)
joblib.dump(le,     "/content/mlp_artifacts/label_encoder.pkl")
joblib.dump(scaler, "/content/mlp_artifacts/scaler.pkl")
print("✅ Encoder + Scaler saved")
# Out:
# ✅ Feature matrix : (38, 4)
# ✅ Weight range   : 82g — 450g  |  Mean: 251.6g
#
# ✅ Train: 30 samples
# ✅ Test : 8  samples
# ✅ Encoder + Scaler saved

# %% [markdown]
# ## Train MLP

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mlp = MLPRegressor(
    hidden_layer_sizes=(256, 128, 64),
    activation='relu',
    solver='adam',
    max_iter=1000,
    learning_rate_init=0.001,
    early_stopping=True,
    validation_fraction=0.15,
    n_iter_no_change=30,
    random_state=42,
    verbose=False,
)

print("⏳ Training MLP...")
mlp.fit(X_train, y_train)
print(f"✅ Done! Iterations: {mlp.n_iter_}")

y_train_pred = mlp.predict(X_train)
y_test_pred  = mlp.predict(X_test)

train_mae  = mean_absolute_error(y_train, y_train_pred)
test_mae   = mean_absolute_error(y_test,  y_test_pred)
train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
test_rmse  = np.sqrt(mean_squared_error(y_test,  y_test_pred))
train_r2   = r2_score(y_train, y_train_pred)
test_r2    = r2_score(y_test,  y_test_pred)

print(f"""
╔══════════════════════════════════════════════════╗
║       MLP WEIGHT ESTIMATOR — FINAL RESULTS       ║
╠══════════════════════════════════════════════════╣
║  Metric        Train Set       Test Set          ║
╠══════════════════════════════════════════════════╣
║  MAE           {train_mae:7.1f}g        {test_mae:7.1f}g         ║
║  RMSE          {train_rmse:7.1f}g        {test_rmse:7.1f}g         ║
║  R² Score      {train_r2:7.3f}         {test_r2:7.3f}          ║
╚══════════════════════════════════════════════════╝
  Train samples : {X_train.shape[0]}
  Test  samples : {X_test.shape[0]}
  Classes       : {len(le.classes_)}
  Segmentation  : SAM-2 (pixel-precise masks) ✅
""")

joblib.dump(mlp, "/content/mlp_artifacts/mlp_weight_estimator.pkl")
print("✅ MLP saved: mlp_weight_estimator.pkl")
# Out:
# ⏳ Training MLP...
# ✅ Done! Iterations: 108
#
# ╔══════════════════════════════════════════════════╗
# ║       MLP WEIGHT ESTIMATOR — FINAL RESULTS       ║
# ╠══════════════════════════════════════════════════╣
# ║  Metric        Train Set       Test Set          ║
# ╠══════════════════════════════════════════════════╣
# ║  MAE              98.3g           96.2g         ║
# ║  RMSE            121.6g          115.7g         ║
# ║  R² Score       -0.539          -0.887          ║
# ╚══════════════════════════════════════════════════╝
#   Train samples : 30
#   Test  samples : 8
#   Classes       : 33
#   Segmentation  : SAM-2 (pixel-precise masks) ✅
#
# ✅ MLP saved: mlp_weight_estimator.pkl

# %% [markdown]
# ## Predicted vs Actual Scatter Plot

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(15, 6))
fig.patch.set_facecolor('#0d1117')

for ax, (y_true, y_pred, title, color) in zip(axes, [
    (y_train, y_train_pred, f"Train  MAE={train_mae:.1f}g  R²={train_r2:.3f}", '#1f6feb'),
    (y_test,  y_test_pred,  f"Test   MAE={test_mae:.1f}g   R²={test_r2:.3f}", '#3fb950'),
]):
    ax.set_facecolor('#161b22')
    ax.scatter(y_true, y_pred, color=color, alpha=0.75,
               edgecolors='white', linewidth=0.5, s=90, zorder=3)
    mn = min(y_true.min(), y_pred.min()) - 10
    mx = max(y_true.max(), y_pred.max()) + 10
    ax.plot([mn, mx], [mn, mx], 'r--', lw=2, label='Perfect prediction')
    ax.set_xlabel('Actual Weight (g)',    color='white', fontsize=11)
    ax.set_ylabel('Predicted Weight (g)', color='white', fontsize=11)
    ax.set_title(f"Predicted vs Actual — {title}",
                 color='white', fontsize=11, fontweight='bold')
    ax.tick_params(colors='white')
    ax.spines[:].set_color('#30363d')
    ax.legend(facecolor='#0d1117', labelcolor='white')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Test Set Bar Chart (Actual vs Predicted)

# %%
test_df = df_features[test_mask].copy().reset_index(drop=True)
test_df['predicted'] = y_test_pred.round(1)
test_df['error_g']   = (test_df['predicted'] - test_df['weight']).abs().round(1)

fig, ax = plt.subplots(figsize=(15, 6))
fig.patch.set_facecolor('#0d1117')
ax.set_facecolor('#161b22')

x     = np.arange(len(test_df))
width = 0.35
ax.bar(x - width/2, test_df['weight'],    width, label='Actual',
       color='#1f6feb', edgecolor='#30363d')
ax.bar(x + width/2, test_df['predicted'], width, label='Predicted',
       color='#3fb950', edgecolor='#30363d', alpha=0.85)

ax.set_xticks(x)
ax.set_xticklabels(
    [f"{r['food_class']}\n({r['weight']}g)" for _, r in test_df.iterrows()],
    rotation=45, ha='right', color='white', fontsize=8
)
ax.set_ylabel('Weight (grams)', color='white', fontsize=11)
ax.set_title('MLP: Actual vs Predicted Weight — Test Set',
             color='white', fontsize=13, fontweight='bold')
ax.tick_params(colors='white')
ax.spines[:].set_color('#30363d')
ax.legend(facecolor='#0d1117', labelcolor='white', fontsize=10)

plt.tight_layout()
plt.show()

print("\n📋 Test Set Detailed Results:")
print(test_df[['food_class','weight','predicted','error_g']].to_string(index=False))
# Out:
# 📋 Test Set Detailed Results:
#     food_class  weight  predicted  error_g
#          kheer     254      179.8     74.2
#     lemon_rice     285      231.9     53.1
#          chole     350      257.5     92.5
# mutton_biryani     380      197.5    182.5
#   nandu_masala     300      232.8     67.2
#    gulab_jamun     210      285.4     75.4
#     lemon_rice     300      291.4      8.6
#  green_chutney      90      306.0    216.0

# %% [markdown]
# ##  Loss Curve + Error Distribution

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
fig.patch.set_facecolor('#0d1117')

# Training loss curve
ax = axes[0]
ax.set_facecolor('#161b22')
ax.plot(mlp.loss_curve_, color='#1f6feb', lw=2, label='Train Loss')
ax.set_xlabel('Iteration', color='white', fontsize=11)
ax.set_ylabel('Loss',      color='white', fontsize=11)
ax.set_title('MLP Training Loss Curve', color='white',
             fontsize=12, fontweight='bold')
ax.tick_params(colors='white')
ax.spines[:].set_color('#30363d')
ax.legend(facecolor='#0d1117', labelcolor='white')

# Error distribution
ax = axes[1]
ax.set_facecolor('#161b22')
errors = y_test_pred - y_test
ax.hist(errors, bins=12, color='#e67e22', edgecolor='#30363d', alpha=0.85)
ax.axvline(0,             color='white',   linestyle='--', lw=2, label='Zero error')
ax.axvline(errors.mean(), color='#f78166', linestyle='-',  lw=2,
           label=f'Mean: {errors.mean():.1f}g')
ax.set_xlabel('Error (Predicted − Actual) grams', color='white', fontsize=10)
ax.set_ylabel('Count',  color='white', fontsize=11)
ax.set_title('Test Set Prediction Error Distribution',
             color='white', fontsize=12, fontweight='bold')
ax.tick_params(colors='white')
ax.spines[:].set_color('#30363d')
ax.legend(facecolor='#0d1117', labelcolor='white')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## SAM-2 Mask Visualization

# %%
sample_rows = df[df['image_path'].notna()].sample(min(6, len(df)), random_state=42).reset_index(drop=True)

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.patch.set_facecolor('#0d1117')
fig.suptitle("Step 2 — SAM-2 Pixel-Precise Segmentation on Custom Dataset",
             fontsize=14, fontweight='bold', color='white')

for ax, (_, row) in zip(axes.flatten(), sample_rows.iterrows()):
    result  = extract_features_with_sam2(
        row['image_path'], yolo_model, predictor, row['food_class']
    )
    img_bgr = cv2.imread(row['image_path'])
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

    if result:
        # Re-run to get mask back (we dropped it from df earlier)
        import torch
        with torch.inference_mode():
            predictor.set_image(img_rgb)
            # get bbox from yolo again
            res  = yolo_model.predict(source=row['image_path'], conf=0.15, verbose=False)[0]
            if res.boxes and len(res.boxes):
                best   = max(res.boxes, key=lambda b: float(b.conf))
                bbox   = np.array([[int(v) for v in best.xyxy[0].tolist()]])
                masks, _, _ = predictor.predict(box=bbox, multimask_output=False)
                mask   = masks[0].astype(np.uint8)

                # Green overlay
                overlay = img_rgb.copy()
                overlay[mask == 1] = [0, 200, 100]
                blended = cv2.addWeighted(img_rgb, 0.55, overlay, 0.45, 0)
                ax.imshow(blended)
                ax.set_title(
                    f"{row['food_class']}\n"
                    f"food_px={mask.sum():,} | ratio={mask.sum()/(img_rgb.shape[0]*img_rgb.shape[1]):.3f}\n"
                    f"actual weight: {row['weight']}g",
                    color='white', fontsize=8
                )
            else:
                ax.imshow(img_rgb)
                ax.set_title(f"{row['food_class']}\n⚠️ No detection", color='red', fontsize=8)
    else:
        ax.imshow(img_rgb)
        ax.set_title(f"{row['food_class']}\n⚠️ No detection", color='red', fontsize=8)

    ax.axis('off')

plt.tight_layout()
plt.show()
